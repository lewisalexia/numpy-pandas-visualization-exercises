# %%
from pydataset import data
# Out:
# initiated datasets repo at: /Users/alexia.lewis/.pydataset/

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# ### 1a

# %% [markdown]
# Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

students_df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(students_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 1b

# %% [markdown]
# Sort the english grades by the passing_english column. How are duplicates handled?

# %%
students_df['passing_english'] = students_df.english >= 70

# %%
students_df
# Out:
#        name  math  english  reading  Cumulative Grade  passing_english
# 0     Sally    62       85       80         75.666667             True
# 1      Jane    88       79       67         78.000000             True
# 2     Suzie    94       74       95         87.666667             True
# 3     Billy    98       96       88         94.000000             True
# 4       Ada    77       92       98         89.000000             True
# 5      John    79       76       93         82.666667             True
# 6    Thomas    82       64       81         75.666667            False
# 7     Marie    93       63       90         82.000000            False
# 8    Albert    92       62       87         80.333333            False
# 9   Richard    69       80       94         81.000000             True
# 10    Isaac    92       99       93         94.666667             True
# 11     Alan    92       62       72         75.333333            False

# %%
students_df.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  Cumulative Grade  passing_english
# 6    Thomas    82       64       81         75.666667            False
# 7     Marie    93       63       90         82.000000            False
# 8    Albert    92       62       87         80.333333            False
# 11     Alan    92       62       72         75.333333            False
# 0     Sally    62       85       80         75.666667             True
# 1      Jane    88       79       67         78.000000             True
# 2     Suzie    94       74       95         87.666667             True
# 3     Billy    98       96       88         94.000000             True
# 4       Ada    77       92       98         89.000000             True
# 5      John    79       76       93         82.666667             True
# 9   Richard    69       80       94         81.000000             True
# 10    Isaac    92       99       93         94.666667             True

# %% [markdown]
# Sorted by index!

# %% [markdown]
# ### 1c

# %% [markdown]
# Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
students_df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# ### 1d

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
students_df.sort_values(by=['passing_english', 'english'], ascending=[True, False])
# Out:
#        name  math  english  reading  Cumulative Grade  passing_english
# 6    Thomas    82       64       81         75.666667            False
# 7     Marie    93       63       90         82.000000            False
# 8    Albert    92       62       87         80.333333            False
# 11     Alan    92       62       72         75.333333            False
# 10    Isaac    92       99       93         94.666667             True
# 3     Billy    98       96       88         94.000000             True
# 4       Ada    77       92       98         89.000000             True
# 0     Sally    62       85       80         75.666667             True
# 9   Richard    69       80       94         81.000000             True
# 1      Jane    88       79       67         78.000000             True
# 5      John    79       76       93         82.666667             True
# 2     Suzie    94       74       95         87.666667             True

# %% [markdown]
# ### 1e

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
students_df['Cumulative Grade'] = round((students_df['math'] + students_df['english'] + students_df['reading']) / 3, 2)

# %%
students_df
# Out:
#        name  math  english  reading  Cumulative Grade  passing_english
# 0     Sally    62       85       80             75.67             True
# 1      Jane    88       79       67             78.00             True
# 2     Suzie    94       74       95             87.67             True
# 3     Billy    98       96       88             94.00             True
# 4       Ada    77       92       98             89.00             True
# 5      John    79       76       93             82.67             True
# 6    Thomas    82       64       81             75.67            False
# 7     Marie    93       63       90             82.00            False
# 8    Albert    92       62       87             80.33            False
# 9   Richard    69       80       94             81.00             True
# 10    Isaac    92       99       93             94.67             True
# 11     Alan    92       62       72             75.33            False

# %% [markdown]
# ## 2a

# %% [markdown]
# How many rows and columns are there?

# %%
# Load the dataset and store it in the variable mpg.

from pydataset import data
mpg = data('mpg')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# ### 2b

# %% [markdown]
# What are the data types of each column?

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# ### 2c

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mpg.info(), mpg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
# (None,
#              displ         year         cyl         cty         hwy
#  count  234.000000   234.000000  234.000000  234.000000  234.000000
#  mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# ...

# %% [markdown]
# ### 2d

# %% [markdown]
# Rename the cty column to city.

# %%
mpg_rename_city = mpg.rename(columns={'cty': 'city'})

# %%
mpg_rename_city.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact

# %% [markdown]
# ### 2e

# %% [markdown]
# Rename the hwy column to highway.

# %%
mpg_rename_highway = mpg_rename_city.rename(columns={'hwy': 'highway'})

# %%
mpg_rename_highway.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %% [markdown]
# ### 2f

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
mpg_rename_highway
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
mpg_rename_highway['city_over_highway'] = (mpg_rename_highway.city - mpg_rename_highway.highway)

# %%
mpg_rename_highway.sort_values('city_over_highway') # no
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  city  \
# 223   volkswagen          new beetle    1.9  1999    4    auto(l4)   f    29
# 107        honda               civic    1.8  2008    4    auto(l5)   f    24
# 1           audi                  a4    1.8  1999    4    auto(l5)   f    18
# 3           audi                  a4    2.0  2008    4  manual(m6)   f    20
# 229   volkswagen              passat    1.8  1999    4    auto(l5)   f    18
# ..           ...                 ...    ...   ...  ...         ...  ..   ...
# 87          ford     f150 pickup 4wd    4.6  1999    8    auto(l4)   4    13
# 127         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# 152       nissan      pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 177       toyota         4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 204       toyota   toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
# ...

# %% [markdown]
# ### 2g

# %% [markdown]
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg_rename_highway['mileage_difference'] = (mpg_rename_highway.highway - mpg_rename_highway.city)

# %%
mpg_rename_highway.sort_values('mileage_difference', ascending = False)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f    18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f    18
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4    14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4    14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
# ...

# %% [markdown]
# ### 2h

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
mpg_rename_highway[mpg_rename_highway['mileage_difference'] 
                   == mpg_rename_highway['mileage_difference'].max()]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  city_over_highway  mileage_difference
# 107  c  subcompact                -12                  12
# 223  d  subcompact                -12                  12

# %%
mpg_rename_highway.mileage_difference == mpg_rename_highway.mileage_difference.max()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# Name: mileage_difference, Length: 234, dtype: bool

# %%
(mpg_rename_highway.mileage_difference == mpg_rename_highway.mileage_difference.max()).value_counts()
# Out:
# False    232
# True       2
# Name: mileage_difference, dtype: int64

# %% [markdown]
# ### 2i

# %% [markdown]
# Which compact class car has the lowest highway mileage? The best?

# %%
mpg_rename_highway['class'].value_counts()
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %% [markdown]
# FILTERING TO SEE ONLY COMPACT CARS and then saving this as a seperate dataframe to manipulate

# %%
mpg_compact = mpg_rename_highway[mpg_rename_highway['class'] =='compact']

# %%
mpg_compact[mpg_compact.highway == mpg_compact.highway.min()]
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  city_over_highway  mileage_difference  average_mileage
# 220  compact                 -7                   7        16.098291

# %%
mpg_compact[mpg_compact.highway == mpg_compact.highway.max()]
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  city_over_highway  mileage_difference  average_mileage
# 213  compact                -11                  11        33.188034

# %% [markdown]
# ### 2j

# %% [markdown]
# Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg_rename_highway['average_mileage'] = (mpg_rename_highway['city'] + mpg_rename_highway['highway']) / 2

# %%
mpg_rename_highway.sort_values(by='average_mileage', ascending = False)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 196       toyota              corolla    1.8  1999    4  manual(m5)   f    26
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
#
# ...

# %% [markdown]
# ### 2k

# %% [markdown]
# Which dodge car has the best average mileage? The worst?

# %%
mpg_dodge = mpg_rename_highway[mpg_rename_highway.manufacturer == 'dodge']

# %%
mpg_dodge.head()
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17       24
# 40        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16       22
# 41        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16       22
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
#
#    fl    class  city_over_highway  mileage_difference  average_mileage
# 38  r  minivan                 -6                   6             21.0
# 39  r  minivan                 -7                   7             20.5
# 40  r  minivan                 -6                   6             19.0
# 41  r  minivan                 -6                   6             19.0
# 42  r  minivan                 -7                   7             20.5

# %%
mpg_dodge[mpg_dodge.average_mileage == mpg_dodge.average_mileage.min()]
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  city_over_highway  mileage_difference  average_mileage
# 55       12  e  pickup                 -3                   3             10.5
# 60       12  e     suv                 -3                   3             10.5
# 66       12  e  pickup                 -3                   3             10.5
# 70       12  e  pickup                 -3                   3             10.5

# %% [markdown]
# ### 3a MAMMALS

# %% [markdown]
# How many rows and columns are there?

# %%
mams = data('Mammals')

# %%
data('Mammals', show_doc=True)
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
mams.shape
# Out:
# (107, 4)

# %% [markdown]
# ### 3b

# %% [markdown]
# What are the data types?

# %%
mams.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# ### 3c

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mams.info(), mams.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
# (None,
#              weight       speed
#  count   107.000000  107.000000
#  mean    278.688178   46.208411
#  std     839.608269   26.716778
#  min       0.016000    1.600000
#  25%       1.700000   22.500000
#  50%      34.000000   48.000000
#  75%     142.500000   65.000000
#  max    6000.000000  110.000000)

# %% [markdown]
# ### 3d

# %% [markdown]
# What is the the weight of the fastest animal?

# %%
mams[mams.speed == mams.speed.max()]
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %% [markdown]
# ### 3e

# %% [markdown]
# What is the overal percentage of specials?

# %%
mams.specials.sum()
# Out:
# 10

# %%
len(mams)
# Out:
# 107

# %%
(mams.specials.sum()/len(mams))*100
# Out:
# 9.345794392523365

# %% [markdown]
# ### 3f

# %% [markdown]
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mams_hop[mams_hop.speed >= mams.speed.median()]
# Out:
#      weight  speed  hoppers  specials  median_spd
# 96      4.6   64.0     True     False       46.21
# 97      4.4   72.0     True     False       46.21
# 98      4.0   72.0     True     False       46.21
# 99      3.5   56.0     True     False       46.21
# 100     2.0   64.0     True     False       46.21
# 101     1.9   56.0     True     False       46.21
# 102     1.5   50.0     True     False       46.21

# %%
len(mams_hop[mams_hop.speed >= mams.speed.median()]) / len(mams) * 100
# Out:
# 6.5420560747663545

# %%
len(mams)
# Out:
# 107
