# %% [markdown]
# ## 1

# %% [markdown]
# Use matplotlib to plot the following equation:

# %%
import matplotlib.pyplot as plt

# %%
import math as m

# %%
import numpy as np

# %% [markdown]
# y = x^2 - x + 2

# %%
x = np.linspace(-10,11)
y = (x**2)- x + 2

plt.plot(x, y)

plt.xlabel('x')
plt.ylabel('y')

plt.annotate('(0,0) here', 
             xy = (0,0),
             xytext = (0,60),
            arrowprops={'arrowstyle':'simple'}
            )
plt.grid()
plt.title('Question 1')
plt.show()

# %% [markdown]
# ## 2

# %% [markdown]
# y=√x

# %%
x = np.linspace(0,10)
y = np.sqrt(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('$y = \sqrt{x}$')
plt.grid()
plt.title('2a')
plt.show()

# %% [markdown]
# y=x**3

# %%
x = np.linspace(-10,10)
y = x**3

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('x**3')
plt.grid()
plt.title('2b')
plt.show()

# %% [markdown]
# y=2**x

# %%
x = np.linspace(0,10)
y = 2**x

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')

plt.grid()
plt.title('2c')
plt.show()

# %% [markdown]
# y=1/(x+1)

# %%
x = np.linspace(-10,10,100)
y = 1/(x+1)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')


plt.grid()
plt.title('2d')
plt.show()

# %% [markdown]
# ## 3

# %% [markdown]
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize =(10,10))
# 1
plt.subplot(2,2,1)
x = np.linspace(-10,11)
y = (x**2)- x + 2

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('$y = \sqrt{x}$')
plt.grid()
plt.title('2a')

# 2
plt.subplot(2,2,2)
x = np.linspace(-10,10)
y = x**3
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('x**3')
plt.grid()
plt.title('$y = x^3$')

# 3
plt.subplot(2,2,3)
x = np.linspace(0,10)
y = 2**x
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('$y = 2^x$')

# 4
plt.subplot(2,2,4)
x = np.linspace(-10,10,100)
y = 1/(x+1)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('$y = 1/(x + 1)$')

plt.show()

# %% [markdown]
# ## 4

# %% [markdown]
# Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
# plot variables
x1 = np.linspace(-10,11)
y1 = (x1**2)- x1 + 2

x2 = np.linspace(-10,10)
y2 = x2**3

x3 = np.linspace(0,10)
y3 = 2**x3

x4 = np.linspace(-10,10,100)
y4 = 1/(x+1)

# plotting variables
plt.plot(x1, y1, c='r', label='2a')
plt.plot(x2, y2, c='b', label='2b')
plt.plot(x3, y3, c='m', label='2c')
plt.plot(x4, y4, c='teal', label='2d')

# set plot limits and labels
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel('x')
plt.ylabel('y')

# plot grid
plt.grid()

# plot title
plt.title('Combination of 2a, 2b, 2c, and 2d')

# plot legend
plt.legend()

# final product
plt.show()

# %%
# Big-O   	Name
# 1   		Constant
# log(n)  	Logarithmic
# n   		Linear
# nlog(n) 	Log Linear
# n^2 		Quadratic
# n^3 		Cubic
# 2^n 		Exponential

import numpy as np
import matplotlib.pyplot as plt

# Stylesheets defined in Matplotlib
plt.style.use('bmh')

# Set up runtime comparisons
n = np.linspace(1, 10, 1000)
labels = ['Constant', 'Logarithmic', 'Linear', 'Log Linear', 'Quadratic', 'Cubic', 'Exponential']
big_o = [np.ones(n.shape), np.log(n), n, n * np.log(n), n**2, n**3, 2**n]

# Plot setup
plt.figure(figsize=(12, 10))
plt.ylim(0, 40)

for i in range(len(big_o)):
    plt.plot(n, big_o[i], label=labels[i])

plt.title('Big-O Notation')
plt.legend(loc=0)
plt.ylabel('Operations')
plt.xlabel('Elements')
plt.show()
